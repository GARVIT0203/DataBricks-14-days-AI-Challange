# %%
# %sql
-- Create structure
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

# %%
# %sql
SHOW TABLES IN workspace.bronze;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ecommerce.bronze.events
USING DELTA
AS
SELECT * FROM workspace.bronze.events;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ecommerce.silver.events
USING DELTA
AS
SELECT * FROM workspace.silver.events

# %%
# %sql
SHOW TABLES IN workspace.gold;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ecommerce.gold.events
USING DELTA
AS
SELECT * FROM workspace.gold.products

# %%
# %sql
create view a
as
select * from workspace.bronze.events

# %%
# %sql
select * from a
